# %% [markdown]
# # Topic Modeling
#
# Using BERTopic

# %% [markdown]
# ## Set up environment

# %%
# !pip install transformers
# !pip install torch
# !pip install datasets
# !pip install bertopic[flair]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My\ Drive/amicus-iv
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/amicus-iv

# %% [markdown]
# Saving locations -- change these for different models!

# %%
model_folder = 'topic-modeling/models/legalbert-RRamicus/'
output_folder = 'topic-modeling/output/legalbert-RRamicus/'

# %% [markdown]
# you'll need to enable GPUs for the notebook:
#
# - Navigate to Edit→Notebook Settings
# - select GPU from the Hardware Accelerator drop-down

# %%
import pandas as pd
import numpy as np
from html import unescape

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from collections import Counter

from transformers import AutoTokenizer
from datasets import load_dataset, load_metric, Dataset

from huggingface_hub import notebook_login

from bertopic import BERTopic
from flair.embeddings import TransformerDocumentEmbeddings

from sklearn.preprocessing import MinMaxScaler
from umap import UMAP
from typing import List
import hdbscan
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ## Define similarity function
#
# We want to group topics based on how similar they are. This is an adoption of the visualize_topics() function

# %%
def get_similar_topics(topic_model,
                     topics: List[int] = None,
                     top_n_topics: int = None,
                     width: int = 650,
                     height: int = 650):
    # Select topics based on top_n and topics args
    if topics is not None:
        topics = list(topics)
    elif top_n_topics is not None:
        topics = sorted(topic_model.get_topic_freq().Topic.to_list()[1:top_n_topics + 1])
    else:
        topics = sorted(list(topic_model.get_topics().keys()))

    # Extract topic words and their frequencies
    topic_list = sorted(topics)
    frequencies = [topic_model.topic_sizes[topic] for topic in topic_list]
    words = [" | ".join([word[0] for word in topic_model.get_topic(topic)[:5]]) for topic in topic_list]

    # seed
    np.random.seed(11)

    # Embed c-TF-IDF into 2D
    all_topics = sorted(list(topic_model.get_topics().keys()))
    indices = np.array([all_topics.index(topic) for topic in topics])
    embeddings = topic_model.c_tf_idf.toarray()[indices]
    embeddings = MinMaxScaler().fit_transform(embeddings)
    embeddings = UMAP(n_neighbors=2, n_components=2, metric='hellinger', random_state=42).fit_transform(embeddings)

    # cluster based on above
    labels = hdbscan.HDBSCAN(min_samples=1, min_cluster_size=3).fit_predict(embeddings)

    # Visualize with plotly
    df = pd.DataFrame({"x": embeddings[1:, 0], "y": embeddings[1:, 1], 'Label':labels[1:],
                       "Topic": topic_list[1:], "Words": words[1:], "Size": frequencies[1:]})
    return df

# %% [markdown]
# ## Data
#
# BERTopic function takes a list of documents, so we need to set this up ourselves.

# %% [markdown]
# ## Option 0: Read in text from drive
#
# I have saved a file on google drive called "data/amicus_text_512.csv" which contains the result of following the steps of option 1 below. since this produces the same results each time, we don't need to keep re-running it.

# %%
df = pd.read_csv('data/amicus_text_clean_512.csv')
df.head(5)
# Out:
#               case            id  \
# 0  Rust v Sullivan  861819857503
# 1  Rust v Sullivan  861819857503
# 2  Rust v Sullivan  861819857503
# 3  Rust v Sullivan  861819857503
# 4  Rust v Sullivan  861819857503
#
#                                                brief  brief_party  \
# 0  Rust v Sullivan. Amici Brief for Respondent, b...            0
# 1  Rust v Sullivan. Amici Brief for Respondent, b...            0
# 2  Rust v Sullivan. Amici Brief for Respondent, b...            0
# 3  Rust v Sullivan. Amici Brief for Respondent, b...            0
# 4  Rust v Sullivan. Amici Brief for Respondent, b...            0
#
#                                                 text
# 0  abortion battle conflict enumerated right life...
# 1  center reproductive health technical ability p...
# 2  erus since made recently fertilized ovum possi...
# 3  breakthroughs may comprise invention new medic...
# 4  ally approximately babies survived extreme sta...

# %% [markdown]
# # Part 0: Train bertopic using fine-tuned transformer
#
# Flair allows you to choose almost any 🤗 transformers model. Select any public model from the HF model hub and pass it to BERTopic.

# %%
model_checkpoint = 'repro-rights-amicus-briefs/legal-bert-base-uncased-finetuned-RRamicus'

# %% [markdown]
# ## Training

# %% [markdown]
# So, we can use our fine-tuned model here! Here, we use bert-base-uncased finetuned (`bbu_ft`) on our reproductive rights amicus.
#
# Note that you have to make the model public in order to do this.
#
# **Only do this once! Skip to 'load saved model' section if this has already been completed**
#
# Takes 9 minutes.

# %%
# init embeddings and model
bbu_ft_embed = TransformerDocumentEmbeddings(model_checkpoint)
bbu_ft_tm = BERTopic(embedding_model=bbu_ft_embed, language = 'english', calculate_probabilities=True, verbose=True)
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at repro-rights-amicus-briefs/legal-bert-base-uncased-finetuned-RRamicus and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# Fit the model to our data (9 mins)

# %%
# fit model
bbu_ft_topics, bbu_ft_probs = bbu_ft_tm.fit_transform(df['text'])
# Out:
# 7590it [05:23, 23.49it/s]
# 2022-03-31 18:57:49,884 - BERTopic - Transformed documents to Embeddings
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)
# 2022-03-31 18:58:42,419 - BERTopic - Reduced dimensionality with UMAP
# 2022-03-31 18:59:20,279 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %% [markdown]
# Save model

# %%
bbu_ft_tm.save(model_folder + 'legalbert_rramicus')
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/_index.py:126: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %% [markdown]
# ## Extract Topics
#
# Only do this once; once saved, skip to next section.

# %%
bbu_ft_freq = bbu_ft_tm.get_topic_info()
bbu_ft_freq.head(10)
# Out:
#    Topic  Count                                       Name
# 0     -1   1979             -1_abortion_court_health_state
# 1      0    316  0_respectfully_counsel_attorney_submitted
# 2      1    131       1_trimester_interest_pregnancy_state
# 3      2    101            2_minor_minors_parental_parents
# 4      3     88            3_madsen_speech_injunction_zone
# 5      4     87  4_federal_jurisdiction_appeal_declaratory
# 6      5     85     5_standing_thirdparty_assert_singleton
# 7      6     77           6_animus_class_interstate_travel
# 8      7     74           7_unborn_child_person_personhood
# 9      8     72        8_griswold_privacy_right_appellants

# %% [markdown]
# Save files -- make sure to change file names!
#
# * topics_model_name.csv = full list of words for each topic
# * topic_classification_model_name.csv = topic classification for each paragraph in the data

# %%
# full list of topics
bbu_full_topics = bbu_ft_tm.get_topics()

#convert full topic dict to df and transpose
topics_df = pd.DataFrame(bbu_full_topics,
                         index=['word1', 'word2', 'word3', 'word4', 'word5', 'word6', 'word7', 'word8', 'word9', 'word10'])\
                         .transpose()

# get just the word
topics_df = topics_df.applymap(lambda x: x[0])

# add col w/concatenated list
#topics_df['all_words'] = topics_df.apply(', '.join, axis=1) #insert at end
topics_df.insert(0, 'topic', topics_df.apply(', '.join, axis=1))

# remove indiv. word columns (word1,...,word10)
topics_df.drop(list(topics_df.filter(regex = 'word')), axis = 1, inplace = True)

# convert index to a column (this is the topic id)
topics_df.insert(0, 'topic_id', topics_df.index)

# add count frequency 
topic_ct = bbu_ft_freq[['Topic', 'Count']]
topics_df = topics_df.merge(topic_ct, how='left', left_on='topic_id', right_on='Topic')
topics_df.drop('Topic', axis=1, inplace=True)

# save
topics_df.to_csv(output_folder + 'topics_legalbert_rramicus.csv', index=False)

# %%
# classification by paragraph
topic_id = bbu_ft_freq[['Topic', 'Name']]
output_df = df.copy()
output_df['topic_id'] = bbu_ft_topics
output_df = output_df.merge(topic_id, how='left', left_on='topic_id', right_on='Topic')
output_df.drop('Topic',axis=1,inplace=True)
output_df.rename({'Name' : 'topic_name'},axis=1, inplace=True)
output_df.to_csv(output_folder + 'topic_classification_legalbert_rramicus.csv', index=False)

# %% [markdown]
# # Part 1: Load Saved Model
#
# Run this code if the previous sections (training, extract topics) have already been run once

# %%
# read in model
bbu_ft_tm = BERTopic.load(model_folder + 'legalbert_rramicus')
# frequency of each topic
bbu_ft_freq = bbu_ft_tm.get_topic_info()
# full topics
bbu_ft_topics = bbu_ft_tm.get_topics()

# %% [markdown]
# ## Investigate topics

# %% [markdown]
# Get similar topics to a word

# %%
similar_topics, similarity = bbu_ft_tm.find_topics("physician", top_n=5)
print(similar_topics)
bbu_ft_tm.get_topic(similar_topics[1])
# Out:
# [221, 308, 30, 1, 10]
# [('adolescents', 0.010568672251375847),
#  ('national', 0.008347920650109343),
#  ('bolton', 0.007635618346580972),
#  ('nonhospital', 0.007278862325871135),
#  ('health', 0.007069897410251013),
#  ('organization', 0.006916993516579048),
#  ('black', 0.0064672655865262415),
#  ('censors', 0.006422766222265313),
#  ('leaflet', 0.005916714514360049),
#  ('doe', 0.005912550652236706)]

# %%
representative_docs = bbu_ft_tm.get_representative_docs(85)
representative_docs
# Out:
# ["2003, pub. l. no. 105, § 2 ( 14 ) ( g ), 117 stat. 1201, 1205 ( “ in addition promoting maternal health, prohibition draw bright line clearly distinguishes abortion infanticide, preserves integrity medical profession, promotes respect human life ” ). kinds concerns, bearing matters moral consequence, protection persons injuries suffered hands other, private persons, concerns traditionally fallen within police powers state local government. traditionally, exclusively. civil rights acts fourteenth amendment, example, authority congress flexed protect people minority races assaults hands private thugs varying degrees organization. could assembled cohorts ku klux klan, members lynching party brought forth ad hoc way, private persons collusion authorities. see, e. g., * 11 united states v. price, 383 u. s. 787 ( 1966 ) ( applying federal statute law enforcement officials killed three civil rights workers ). difficulty civil rights analogy, though, context civil rights act, congress reaching private conduct states failed act ( or worse, acted collusion private actors ), depriving persons within jurisdiction equal protection laws truest meaning phrase. state action here. quite contrary - many states persisted attempts protect weakest innocent fellow human beings despite court's series abortion rulings since 1973. 3 * 12 end matter, course. distinction “ citizen ” ( defined “ born ” united states subject jurisdiction ) privileges immunities clause fourteenth amendment “ person ” due process equal protection clauses certainly lends credible argument “ persons ” conceived yet born fall umbrella latter two clauses. admittedly, distinction appear within contemplation drafted ratified constitution, lack attention subject undoubtedly practice contrary basic human rights - inalienable right life, use declaration's phrase - rather citizens legislators day thought abortion acceptable. result, presume fourteenth amendment meant exclude children womb class “ persons ” protected fourteenth amendment merely subject abortion debated 1866. court recognized contexts, example, word “ persons ” encompasses wider category word “ citizens. ” visitors abroad, resident aliens, illegal immigrants alike may protected lawless assault lives even without need show passports papers citizenship, cannot deprived life liberty without due process, merely “ persons. ” see, e. g., plyler v. doe, 457 u. s. 202, 211 - 212 ( 1982 ) ; yick wo v. hopkins, 118 u. s. 356, 369 ( 1886 ). commonsense understanding, “ persons ” human beings. ask human beings come * 13 protection laws virtually ask : come exist? inalienable rights “ persons ” attach? answer given james",
#  "protection would undermine careful reasoned judgments made states regarding effectively expend limited public resources allowing certain states outsource responsibility maintaining critical services programs protecting women's health. history shows many women cross state lines, means so, abortions unavailable states residence. example, period less three years new york liberalized abortion laws 1970, nearly 350, 000 women came states abortions entirely largely unavailable. 22 recent years, several states experienced substantial influx patients seeking abortions following enactment onerous abortion restrictions neighboring states. 23 course, many women - - especially indigent women [ * 45 ] others unable travel different jurisdictions - - this court's departure federal constitutional protections would result elimination access abortion services. amici - - many support subsidize full range reproductive health care services within states - - stand ready willing provide services need them. however, court abandons robust federal constitutional protections abortion access, certain states reasonably expect significant sometimes sudden increases number out - of - state patients seeking abortion services jurisdictions remain available. states also reasonably expect meaningful increases number out - of - state patients seeking later - term abortions, many women may delay obtaining services able obtain adequate funds interstate travel. increases, especially sudden, could strain states'health care systems, impair availability care, burden reproductive choices residents non - residents alike. ability states continue support wide range reproductive health [ * 46 ] care services - - including abortion well prenatal postpartum care - - could substantially threatened responsibility ensuring women need abortions able safely obtain services somewhere country. court affirm federal constitutional protections abortion access prevent certain states - - namely would eliminate abortion access within borders - - from shifting costs protecting women's health states would maintain commitment woman's right choose terminate pre - viability pregnancy basic human right critical public health measure. conclusion judgment united states court appeals fifth circuit reversed. respectfully submitted, letitia james attorney generalstate new york barbara d. underwood * solicitor general andrea oser deputy solicitor general ester murdukhayeva assistant solicitor general barbara. underwood @ ag. ny. gov * counsel record december 2019 xavier becerra attorney generalstate california p. o. box 944255 sacramento, ca 94244 phil weiser attorney general [ * 47 ] state colorado 1300 broadway, 10th fl. denver, co 80203 william tong attorney generalstate connecticut 165 capitol ave. hartford, ct 06106 kathleen jennings attorney generalstate delaware 820 n. french st. wilmington, de 19801 clare e. connors attorney generalstate hawai'i 425 queen st. honolulu",
#  "32. 15 even * 24 absence sort history violence blockades exists context reproductive health care facilities. 16 here, especially light history, restrictions conduct purpose protecting access reproductive health care upheld, well. contexts, “ exercise free speech rights conflicts another fundamental right, ” court held restriction speech satisfied even exacting scrutiny. burson v. freeman, 504 u. s. 191, 211 ( 1992 ). example, burson, court upheld ordinance required solicitors stand 100 feet entrances polling places ground government compelling interest protecting fundamental right vote without “ intimidation fraud. ” id. again, court approved content - based restriction speech without showing history violence blockades. id. contrast, findings persistent harassment, intimidation blockades threaten health well - being persons seeking exercise fundamental right access reproductive health care. 17 * 25 accordingly, justification imposing restriction activities anti - abortion protesters case even stronger supporting restriction burson. physical assaults blockades expressive conduct protected first amendment. wisconsin v. mitchell, 508 u. s. 476, 484 ( 1993 ) ( citing roberts v. united states jaycees, 468 u. s. 609, 628 ( 1984 ) ). fact conduct may engaged purpose expressing point view cloak conduct protections afforded speech. id. 2199 ( citing united states v. o'brien, 391 u. s. 367, 376 ( 1968 ) ). further, “ ‘ it never deemed abridgment freedom speech press make course conduct illegal merely conduct part initiated, evidenced, carried means language, either spoken, written, printed. ” ’ cox, 379 u. s. 555 ( quoting giboney v. empire storage & ice co., 336 u. s. 490 ( 1949 ) ). none principles less sound context abortion. simply “ the context abortion, ” court depart “ first amendment precedents traditions.... ” madsen, 114 s. ct. 2534 - 355 ( scalia, j., dissenting ). court long recognized “ acts isolation peaceful may part coercive thrust entangled acts violence. ” milk wagon drivers, 312 u. s. 294 ( permitting restriction picketing enmeshed violence ). record violence blockades, nationwide buffalo, new york, significant enough cause congress * 26 provide federal cause action. house report 7 ; senate report 9. also significant enough warrant sufficiently broad judicial remedy. conclusion states interest ensuring safe orderly access health care, including reproductive health care. interest encompasses concomitant interests controlling burdens on, costs of, law enforcement,"]

# %% [markdown]
# ## Visualize Topics

# %%
bbu_ft_tm.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="77e3b818-6e64-488c-b7fc-451fb0b2dbee" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77e3b818-6e64-488c-b7fc-451fb0b2dbee")) {                    Plotly.newPlot(                        "77e3b818-6e64-488c-b7fc-451fb0b2dbee",                        [{"customdata":[[0,"respectfully | counsel | submitted | conclusion | curiae",411],[1,"minor | parental | parents | notification | minors",295],[2,"extortion | hobbs | property | commerce | robbery",198],[3,"roe | fundamental | privacy | liberty | wade",156],[4,"title | regulations | 1008 | secretary | funds",155],[5,"injunction | madsen | speech | feet | clinic",154],[6,"standing | party | third | assert | singleton",145],[7,"1985 | animus | class | gender | interstate",130],[8,"content | hill | zone | buffer | speech",129],[9,"partial | nebraska | ban | exception | procedure",111],[10,"3205 | physician | information | informed | pennsylvania",109],[11,"decisis | stare | roe | wade | precedent",88],[12,"compelling | 428 | danforth | scrutiny | strict",81],[13,"jurisdiction | appeal | declaratory | huffman | federal",77],[14,"false | supreme | evidence | killings | murder",71],[15,"enterprise | rico | 1962 | racketeering | economic",68],[16,"620 | hellerstedt | burdens | fifth | louisiana",67],[17,"appellants | unborn | child | right | life",66],[18,"laura | women | jo | dr | abortion",62],[19,"undue | burden | casey | prong | connor",61],[20,"equitable | 1964 | relief | rico | remedies",52],[21,"unborn | child | 2d | tort | mother",51],[22,"2015 | recording | amber | pregnancy | 911",50],[23,"brookfield | picketing | streets | residential | forum",48],[24,"poor | georgia | equal | white | shall",48],[25,"griswold | bear | privacy | mccann | babbitz",47],[26,"religious | religion | conscientious | belief | establishment",45],[27,"2015 | texas | 2014 | drug | asc",44],[28,"tr | intact | chasen | dr | dismemberment",43],[29,"asc | rational | gonzales | undue | burden",42],[30,"any | dr | unborn | clinic | uhlenberg",41],[31,"maher | funding | 432 | poelker | childbirth",40],[32,"sterilization | abortions | births | 1971 | ratio",39],[33,"university | guttmacher | representative | pregnancy | unintended",37],[34,"congress | findings | legislative | federal | corollary",35],[35,"pain | gender | classifications | abolitionists | salvi",33],[36,"posterity | estate | framer | perpetuities | preamble",31],[37,"credentialing | privileges | hospital | 01 | privileging",29],[38,"mathematics | stubblefield | elementary | counting | employs",28],[39,"population | wicklund | fgi | guidelines | cnty",28],[40,"speech | content | restraint | frisby | expression",27],[41,"amy | church | ogc | rogers | title",26],[42,"xix | assistance | services | plan | medically",26],[43,"monitoring | city | adolescent | adolescents | guam",25],[44,"generalstate | stephanie | attorney | market | st",25],[45,"anne | recording | video | 911 | 2015",25],[46,"fetus | hb2 | personhood | ms | klan",25],[47,"century | riverside | york | pba | floating",24],[48,"patient | informed | disclosure | information | physician",24],[49,"davis | senator | countries | mortality | morbidity",24],[50,"competing | issues | legislative | resolution | policy",23],[51,"641 | league | waiting | period | 2d",23],[52,"deaths | courts | ul0 | york | b0",23],[53,"rutherford | institute | rudolph | privileges | paragraph",23],[54,"precedent | stare | decisis | ct | unworkable",23],[55,"dred | scott | mental | christianity | recognize",23],[56,"jcah | laurie | standards | brewer | persons",22],[57,"2019 | incl | 911 | link | call",22],[58,"rate | fell | church | 1980 | religious",22],[59,"counseling | viability | persons | captive | intact",22],[60,"3210 ...

# %% [markdown]
# ## Topics per class

# %% [markdown]
# We can divide up the topics into those that appear in one class vs the other (fem briefs and opp briefs)

# %%
topics_per_class = bbu_ft_tm.topics_per_class(sequences, bbu_ft_topics, brief_party)
topics_per_class.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-08b83b6b1868> in <module>()
# ----> 1 topics_per_class = bbu_ft_tm.topics_per_class(sequences, bbu_ft_topics, brief_party)
#       2 topics_per_class.head(10)
#
# NameError: name 'sequences' is not defined

# %%
#fem_brief_bbu_topics = topics_per_class[topics_per_class['Class']==1].drop(['Class'],axis=1,inplace=False)
bbu_ft_tm.visualize_topics_per_class(topics_per_class, top_n_topics=5, normalize_frequency=True)

# %% [markdown]
# ## Reduce n topics
#
# This is a manual decision -- skip for now, this will be done later after we select a model!

# %%
#new_topics, new_probs = topic_model.reduce_topics(df['text'], topics, probs, nr_topics=60)

# %% [markdown]
# ## Topic hierarchy
#
# Another way to visually examine how topcis are related to one another. Just from looking on this, I think it would make more sense to topic model pro-women and pro-opp briefs separately, since they often use similar language/topics but are articulating very different points on them!

# %%
topic_model.visualize_hierarchy(top_n_topics=25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-ca05dc7f85d9> in <module>()
# ----> 1 topic_model.visualize_hierarchy(top_n_topics=25)
#
# NameError: name 'topic_model' is not defined

# %% [markdown]
# ## Topic Similarity
#
# Having generated topic embeddings, through both c-TF-IDF and embeddings, we can create a similarity matrix by simply applying cosine similarities through those topic embeddings. The result will be a matrix indicating how similar certain topics are to each other.

# %%
topic_model.visualize_heatmap(n_clusters=10, width=1000, height=1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-8fe560e405b8> in <module>()
# ----> 1 topic_model.visualize_heatmap(n_clusters=10, width=1000, height=1000)
#
# NameError: name 'topic_model' is not defined

# %% [markdown]
# # Part 2: Seed topics (*skip*)
#
# https://maartengr.github.io/BERTopic/api/bertopic.html

# %%
seed_topic_list = [['physician', 'doctor', 'medical professional', 'medical expert'], ['women', 'mother']]
seed_topic_model = BERTopic(language = 'english', calculate_probabilities=True, verbose=True,
                            seed_topic_list = seed_topic_list)
seed_topics, seed_probs = seed_topic_model.fit_transform(sequences)
# Out:
# Batches:   0%|          | 0/498 [00:00<?, ?it/s]
# 2022-03-16 17:40:37,439 - BERTopic - Transformed documents to Embeddings
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2022-03-16 17:41:03,827 - BERTopic - Reduced dimensionality with UMAP
# 2022-03-16 17:41:24,975 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %%
seed_freq = seed_topic_model.get_topic_info()
seed_freq.head(10)
# Out:
#    Topic  Count                                        Name
# 0     -1   5744                            -1_the_to_of_and
# 1      0    473             0_parental_minors_parents_minor
# 2      1    372          1_court_federal_courts_legislative
# 3      2    303  2_mortality_pregnancy_complications_deaths
# 4      3    265                   3_hill_zone_buffer_speech
# 5      4    224                    4_roe_privacy_wade_right
# 6      5    200        5_louisiana_620_privileges_admitting
# 7      6    180          6_psychological_women_study_mental
# 8      7    179          7_children_parents_family_parental
# 9      8    171                       8_human_life_being_we

# %%
seed_women_similar_topics, seed_women_similarity = seed_topic_model.find_topics("women's rights", top_n=5)
print(seed_women_similar_topics)
seed_topic_model.get_topic(seed_women_similar_topics[0])
# Out:
# [165, 139, 86, 91, 127]
# [('women', 0.014136297774918507),
#  ('laws', 0.011999050580616942),
#  ('illegal', 0.010237065081556607),
#  ('enforcement', 0.009734576408527344),
#  ('dying', 0.0094023498417061),
#  ('abortions', 0.009385982433003582),
#  ('rape', 0.008878073201327344),
#  ('incest', 0.008369399996816313),
#  ('prosecution', 0.0077237846543999214),
#  ('criminal', 0.007508319106164667)]

# %%
seed_phys_similar_topics, seed_phys_similarity = seed_topic_model.find_topics("doctor", top_n=5)
print(seed_phys_similar_topics)
seed_topic_model.get_topic(seed_phys_similar_topics[1])
# Out:
# [164, 66, 77, 93, 11]
# [('hospital', 0.02913038745081937),
#  ('credentialing', 0.025738828794159216),
#  ('privileges', 0.022390621401369354),
#  ('hospitals', 0.019021824083630595),
#  ('care', 0.016055733923885766),
#  ('staff', 0.015923603500972786),
#  ('physician', 0.015268006792430806),
#  ('ms', 0.015124700368570216),
#  ('admitting', 0.012263187376225206),
#  ('physicians', 0.011998829970855503)]

# %% [markdown]
# # Part 3: Split into fem and opp

# %% [markdown]
# In this section, we fit models for fem and opp briefs separately in order to get more specific topic information.

# %% [markdown]
# Experiment with removing additional words
#
# numbers (including “fifth”, “ii”, “2d”, etc), dates (“1923”), “et” & “al”, “per”, “circuit” “district”, some acronyms (e.g., ussc, www), some proper names (thorp, hollen), case names (Akron, Casey))

# %%
df_clean = df.copy()
#df_clean['text'] = df_clean['text'].str.replace('[{}]'.format(string.punctuation), '')

rmv_list = ['ii', 'https', 'al', 'et', 'per', 'www', 'llp', 'id', 'nos', 'pdf', 'http',
            'ul', 'fi', 'ri', 'sb', 'ql', 'li', 'fs',
            'circuit', 'district', 'supra', 'supp', 'decisis', 'amici', 'curiae', 'court', 'courts', 'supreme', 'appeals',
            'appeal', 'appellants', 'appellant', 'appellee', 'appellees',
            'first', 'second', 'third', 'fourth', 'fifth', 'sixth', 'seventh', 'eighth', 'nineth', 'tenth', 'eleventh', 'twelfth']

df_clean['text'] = df_clean['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (rmv_list)]))
#df_clean['text_2'] = df_clean['text'].apply(lambda x: [word for word in x.split()])

# %% [markdown]
# Split data into fem and opp

# %%
# split data
opp_df = df_clean[df_clean['brief_party']==0]
fem_df = df_clean[df_clean['brief_party']==1]

# %% [markdown]
# ## Fem topic model

# %% [markdown]
# ### Initial train + save

# %% [markdown]
# Init existing topic model again so we don't over-write existing model.

# %%
fem_tm = BERTopic.load(model_folder + 'legalbert_rramicus')

# %% [markdown]
# Fit the model on only the docs of interest (5 min)

# %%
# fit model
fem_topics, fem_probs = fem_tm.fit_transform(fem_df['text'])
# Out:
# 3461it [02:26, 23.70it/s]
# 2022-03-31 19:04:57,290 - BERTopic - Transformed documents to Embeddings
# 2022-03-31 19:05:35,604 - BERTopic - Reduced dimensionality with UMAP
# 2022-03-31 19:05:36,089 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %%
fem_topic_info = fem_tm.get_topic_info()
fem_topic_info.head(5)
# Out:
#    Topic  Count                                        Name
# 0      0   1619                0_abortion_women_health_care
# 1     -1    574              -1_abortion_state_health_women
# 2      1    140        1_injunction_petitioners_zone_speech
# 3      2    128  2_respectfully_counsel_conclusion_attorney
# 4      3     71             3_minors_minor_parental_parents

# %%
fem_full_topics = fem_tm.get_topics()

# %% [markdown]
# Save

# %%
# full list of topics
fem_full_topics = fem_tm.get_topics()

#convert full topic dict to df and transpose
topics_df = pd.DataFrame(fem_full_topics,
                         index=['word1', 'word2', 'word3', 'word4', 'word5', 'word6', 'word7', 'word8', 'word9', 'word10'])\
                         .transpose()

# get just the word
topics_df = topics_df.applymap(lambda x: x[0])

# add col w/concatenated list
#topics_df['all_words'] = topics_df.apply(', '.join, axis=1) #insert at end
topics_df.insert(0, 'topic', topics_df.apply(', '.join, axis=1))

# remove indiv. word columns (word1,...,word10)
topics_df.drop(list(topics_df.filter(regex = 'word')), axis = 1, inplace = True)

# convert index to a column (this is the topic id)
topics_df.insert(0, 'topic_id', topics_df.index)

# add count frequency 
topic_ct = fem_topic_info[['Topic', 'Count']]
topics_df = topics_df.merge(topic_ct, how='left', left_on='topic_id', right_on='Topic')
topics_df.drop('Topic', axis=1, inplace=True)

# save
topics_df.to_csv(output_folder + 'fem_topics_clean_legalbert_rramicus.csv', index=False)

# classification by paragraph
topic_id = fem_topic_info[['Topic', 'Name']]
output_df = fem_df.copy()
output_df['topic_id'] = fem_topics
output_df = output_df.merge(topic_id, how='left', left_on='topic_id', right_on='Topic')
output_df.drop('Topic',axis=1,inplace=True)
output_df.rename({'Name' : 'topic_name'},axis=1, inplace=True)
output_df.to_csv(output_folder + 'fem_topic_clean_classification_legalbert_rramicus.csv', index=False)

# %% [markdown]
# Next, cluster the topics using hdbscan

# %%
fem_embed = get_similar_topics(fem_tm)

# %%
fem_topic_df = pd.read_csv(output_folder + 'fem_topics_clean_legalbert_rramicus.csv')
fem_embed = fem_embed.sort_values('Label')
fem_embed.rename({'Topic':'topic_id', 'Label':'label'}, axis=1, inplace=True)
fem_embed = fem_embed.merge(fem_topic_df, how='left', on = 'topic_id')
fem_embed.drop(['Words', 'Size'], axis=1, inplace=True)
fem_embed = fem_embed[['topic_id', 'label', 'topic', 'Count', 'x', 'y']]
fem_embed.to_csv(output_folder + 'fem_topics_clean_labels_legalbert_rramicus.csv')

# %% [markdown]
# Save model

# %%
fem_tm.save(model_folder + 'fem_legalbert_rramicus')

# %% [markdown]
# ### Load from saved

# %%
fem_tm = BERTopic.load(model_folder + 'fem_bbu_rramicus')
# Out:
# Downloading:   0%|          | 0.00/664 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/321 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %% [markdown]
# ### Explore

# %%
fem_tm.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b832f202-4549-496a-afb9-f636b8617b9b" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b832f202-4549-496a-afb9-f636b8617b9b")) {                    Plotly.newPlot(                        "b832f202-4549-496a-afb9-f636b8617b9b",                        [{"customdata":[[0,"minors | parental | parents | notification | adolescents",195],[1,"counsel | respectfully | street | submitted | curiae",136],[2,"child | old | would | could | children",111],[3,"clinic | clinics | violence | dr | anti",92],[4,"women | texas | al | http | note",90],[5,"woman | court | state | supra | women",70],[6,"casey | women | id | health | burden",64],[7,"interest | state | court | compelling | woman",64],[8,"physician | title | consent | akron | woman",59],[9,"right | court | roe | wade | fundamental",58],[10,"right | state | rights | court | property",57],[11,"injunction | petitioners | clinic | conduct | content",56],[12,"court | fetus | cases | appeal | state",54],[13,"texas | women | abortion | wait | clinics",51],[14,"zone | buffer | facility | petitioners | feet",50],[15,"conclusion | court | appeals | reasons | foregoing",49],[16,"trimester | weeks | pregnancy | fetus | intact",40],[17,"buffer | zone | content | speech | hill",37],[18,"rape | partner | violence | victims | intimate",36],[19,"intact | tr | chasen | study | dr",35],[20,"scrutiny | right | privacy | court | roe",35],[21,"york | abortions | new | births | abortion",34],[22,"hobbs | extortion | property | act | robbery",34],[23,"hyde | medicaid | xix | amendment | medically",32],[24,"enterprise | rico | economic | racketeering | organized",30],[25,"madsen | injunction | buffer | zone | speech",30],[26,"fetus | person | donor | laws | interest",30],[27,"roe | rights | right | government | constitutional",30],[28,"trimester | second | akron | abortions | period",30],[29,"hospital | privileges | credentialing | hospitals | staff",28],[30,"poverty | people | african | al | louisiana",26],[31,"privacy | right | griswold | marital | fundamental",26],[32,"woman | child | women | unwanted | pregnancy",24],[33,"decisis | stare | roe | precedent | wade",24],[34,"brookfield | picketing | residential | ordinance | streets",24],[35,"church | religious | moral | life | methodist",24],[36,"louisiana | women | black | outcomes | act",24],[37,"right | decision | roe | liberty | casey",24],[38,"viewpoint | speech | public | government | first",23],[39,"minor | parental | notification | bellotti | parents",22],[40,"email | received | amicus | school | amici",21],[41,"privileges | admitting | whole | district | fifth",20],[42,"scrutiny | court | courts | deference | findings",20],[43,"texas | privileges | abortion | admitting | fedor",19],[44,"care | quality | payment | health | cost",19],[45,"century | nineteenth | abortion | twentieth | became",18],[46,"sterilization | trimester | procedures | performed | prostaglandin",18],[47,"university | college | new | california | york",17],[48,"physician | counseling | abortion | patient | professionals",17],[49,"must | nursing | facility | counseling | patient",17],[50,"organization | rights | national | reproductive | women",17],[51,"liberty | fourteenth | amendment | cong | rights",17],[52,"rescue | operation | interstate | gay | rights",16],[53,"punishment | amendment | servitude | involuntary | eighth",16],[54,"court | act | fifth | casey | burdens",16],[55,"respectfully | women | counsel | people | abortion",16],[56,"hospital | medical | abortion | ph | trimester",15],[57,"roe | wade | privacy | court | right",15],[58,"state | right | life | woman | roe",15],[59,"obergefell | sex | equal | dignity | same",13],[60,"equitable | relief | subsection | rico | section",13], ...

# %% [markdown]
# Find topics

# %%
similar_topics, similarity = fem_tm.find_topics("medical", top_n=5)
print(similar_topics)
print(similarity)
for i in range(len(similar_topics)):
  print(fem_tm.get_topic(similar_topics[i]))
# Out:
# [57, 46, -1, 35, 59]
# [0.9860490372255521, 0.9815115778404839, 0.9811166197960979, 0.9800830365274396, 0.9793343559125567]
# [('act', 0.01543954118686647), ('emergency', 0.014231235818460135), ('medical', 0.013855040367193103), ('physician', 0.01369661624339168), ('patient', 0.013609853728641), ('hampshire', 0.012316739126711787), ('health', 0.012138903189156435), ('abortion', 0.01207191176826808), ('physicians', 0.011911218625010789), ('judge', 0.011798782385998659)]
# [('organization', 0.03879029805705921), ('rights', 0.028612205730736546), ('reproductive', 0.02238318008521494), ('national', 0.021545567586049752), ('women', 0.021178794951134908), ('civil', 0.01938167511672356), ('legal', 0.01754986814847482), ('education', 0.016915347950587963), ('health', 0.01645128531672538), ('advocacy', 0.015872087366163745)]
# [('court', 0.009003044817547996), ('abortion', 0.0078714103351809), ('state', 0.007542976329646191), ('right', 0.006502928377333628), ('health', 0.006451944211089597), ('women', 0.00628211346849032), ('woman', 0.006266423372504197), ('see', 0.005985952998052546), ('medical', 0.005910533099113882), ('statute', 0.005828952477247492)]
# [('minor', 0.02253664294520492), ('physician', 0.01911903029869337), ('medical', 0.015238959521692418), ('1870', 0.014850782318519393), ('parental', 0.014478006661840431), ('patient', 0.013909005609166008), ('section', 0.013478723873516106), ('necessary', 0.012748268196019664), ('statute', 0.012067505073100435), ('fetus', 0.011917770854811872)]
# [('rico', 0.02617814602973453), ('congress', 0.024102471945680673), ('organized', 0.020998641848315364), ('crime', 0.020592061873714665), ('commerce', 0.019500427911417536), ('interstate', 0.01721731870925849), ('sedima', 0.017130593781134563), ('economic', 0.014819023408373594), ('statute', 0.014761372583071015), ('statutory', 0.014756120240439744)]

# %% [markdown]
# ## Opp topic model

# %% [markdown]
# ### Initial train + save

# %% [markdown]
# Init existing topic model again so we don't over-write existing model.

# %%
opp_tm = BERTopic.load(model_folder + 'legalbert_rramicus')

# %% [markdown]
# Fit the model on only the docs of interest (5 min)

# %%
# fit model
opp_topics, opp_probs = opp_tm.fit_transform(opp_df['text'])
# Out:
# 4129it [03:01, 22.69it/s]
# 2022-03-31 19:11:20,390 - BERTopic - Transformed documents to Embeddings
# 2022-03-31 19:11:37,142 - BERTopic - Reduced dimensionality with UMAP
# 2022-03-31 19:11:40,134 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %%
opp_topic_info = opp_tm.get_topic_info()
opp_topic_info.head(5)
# Out:
#    Topic  Count                                         Name
# 0     -1   1048                  -1_abortion_roe_state_right
# 1      0    188  0_respectfully_submitted_counsel_conclusion
# 2      1    184              1_parental_parents_minor_minors
# 3      2    162               2_hobbs_extortion_property_act
# 4      3    129                 3_murder_evidence_any_unborn

# %% [markdown]
# Save

# %%
# full list of topics
opp_full_topics = opp_tm.get_topics()

#convert full topic dict to df and transpose
topics_df = pd.DataFrame(opp_full_topics,
                         index=['word1', 'word2', 'word3', 'word4', 'word5', 'word6', 'word7', 'word8', 'word9', 'word10'])\
                         .transpose()

# get just the word
topics_df = topics_df.applymap(lambda x: x[0])

# add col w/concatenated list
#topics_df['all_words'] = topics_df.apply(', '.join, axis=1) #insert at end
topics_df.insert(0, 'topic', topics_df.apply(', '.join, axis=1))

# remove indiv. word columns (word1,...,word10)
topics_df.drop(list(topics_df.filter(regex = 'word')), axis = 1, inplace = True)

# convert index to a column (this is the topic id)
topics_df.insert(0, 'topic_id', topics_df.index)

# add count frequency 
topic_ct = opp_topic_info[['Topic', 'Count']]
topics_df = topics_df.merge(topic_ct, how='left', left_on='topic_id', right_on='Topic')
topics_df.drop('Topic', axis=1, inplace=True)

# save
topics_df.to_csv(output_folder + 'opp_topics_clean_legalbert_rramicus.csv', index=False)

# classification by paragraph
topic_id = opp_topic_info[['Topic', 'Name']]
output_df = opp_df.copy()
output_df['topic_id'] = opp_topics
output_df = output_df.merge(topic_id, how='left', left_on='topic_id', right_on='Topic')
output_df.drop('Topic',axis=1,inplace=True)
output_df.rename({'Name' : 'topic_name'},axis=1, inplace=True)
output_df.to_csv(output_folder + 'opp_topic_clean_classification_legalbert_rramicus.csv', index=False)

# %% [markdown]
# Next, cluster the topics using hdbscan

# %%
opp_embed = get_similar_topics(opp_tm)

# %%
opp_topic_df = pd.read_csv(output_folder + 'opp_topics_clean_legalbert_rramicus.csv')
opp_embed = opp_embed.sort_values('Label')
opp_embed.rename({'Topic':'topic_id', 'Label':'label'}, axis=1, inplace=True)
opp_embed = opp_embed.merge(opp_topic_df, how='left', on = 'topic_id')
opp_embed.drop(['Words', 'Size'], axis=1, inplace=True)
opp_embed = opp_embed[['topic_id', 'label', 'topic', 'Count', 'x', 'y']]
opp_embed.to_csv(output_folder + 'opp_topics_clean_labels_legalbert_rramicus.csv')

# %%
opp_tm.save(model_folder + 'opp_legalbert_rramicus')
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/_index.py:126: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %% [markdown]
# ### Load from saved

# %%
opp_tm = BERTopic.load(model_folder + 'opp_bbu_rramicus')

# %% [markdown]
# ### Explore

# %%
#opp_tm.visualize_topics(top_n_topics=50)
opp_tm.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="67f23490-366d-4378-81f0-ae70790c1f33" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67f23490-366d-4378-81f0-ae70790c1f33")) {                    Plotly.newPlot(                        "67f23490-366d-4378-81f0-ae70790c1f33",                        [{"customdata":[[0,"respectfully | submitted | counsel | conclusion | attorney",188],[1,"parental | parents | minor | minors | notification",184],[2,"hobbs | extortion | property | act | rico",162],[3,"murder | evidence | any | unborn | false",129],[4,"standing | thirdparty | singleton | providers | assert",83],[5,"funding | maher | state | abortions | poelker",80],[6,"personhood | human | roe | life | fourteenth",79],[7,"hellerstedt | casey | wwh | test | burden",76],[8,"privileges | admitting | louisiana | providers | hospital",65],[9,"salerno | facial | statute | exception | stenberg",64],[10,"travel | animus | interstate | class | gender",56],[11,"speech | public | picketing | streets | forum",56],[12,"roe | stare | decisions | precedent | overruling",55],[13,"right | unborn | child | life | privacy",48],[14,"undue | burden | oconnor | standard | akron",47],[15,"aye | abortion | fetus | parents | child",46],[16,"title | funds | program | section | services",44],[17,"undue | casey | prong | burden | gonzales",43],[18,"federal | jurisdiction | declaratory | threejudge | huffman",43],[19,"posterity | constitution | preamble | rights | powers",40],[20,"statute | construction | vagueness | state | interpretation",39],[21,"hill | speech | zone | message | buffer",36],[22,"partialbirth | procedure | intact | fetus | act",35],[23,"child | unborn | property | torts | person",33],[24,"posterity | abortion | women | person | human",30],[25,"pregnancy | behavior | abortion | ban | public",26],[26,"rate | birth | olds | women | year",26],[27,"injunction | madsen | speech | clinic | zone",22],[28,"informed | information | pard | par | consent",21],[29,"plaintiffs | asc | closed | admittingprivileges | clinics",20],[30,"lincoln | roe | activists | dred | universe",19],[31,"abortion | fertilization | asc | church | lisa",17],[32,"appropriations | appropriation | congress | money | treasury",16],[33,"induced | ectopic | pregnancy | incidence | subsequent",16],[34,"ann | boyfriend | pressured | code | funeral",15],[35,"human | persons | information | privacy | life",15],[36,"unborn | child | homicide | wrongful | cal",15],[37,"age | pregnancies | survey | group | jane",15],[38,"partial | moral | status | birth | abortion",15],[39,"fetus | johnson | uterus | birth | risk",15],[40,"minneapolis | technologies | age | increase | teens",15],[41,"women | gosnell | abortion | task | wilson",15],[42,"content | contentbased | sign | ward | contentneutral",15],[43,"rep | recording | video | pain | lung",15],[44,"abortion | woman | infanticide | procedure | minnesota",15],[45,"maternal | saline | retained | monitoring | mortality",15],[46,"pregnancy | abortion | francisco | woman | medical",15],[47,"mathematical | girls | saline | survey | information",15],[48,"irl | report | deficiencies | nonwhite | patient",15],[49,"women | abortion | husbands | patient | task",15],[50,"declaration | law | united | murder | parents",15],[51,"declaration | independence | deaths | pregnancy | information",14],[52,"girls | parental | international | haskell | involvement",14],[53,"failure | inherently | would | tissue | liberty",14],[54,"sexual | abuse | parents | parental | pathology",14],[55,"abortion | infanticide | mortality | health | child",14],[56,"pard | par | cong | liri | murder",14],[57,"abortion | elective | abortions | baby | therapeutic",14],[58,"title | pard | par | liri | women",14],[59,"eisenmengers | pard | par |  ...

# %% [markdown]
# # Topic Modeling
#
# Using BERTopic

# %% [markdown]
# ## Set up environment

# %%
# !pip install transformers
# !pip install torch
# !pip install datasets
# !pip install bertopic[flair]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My\ Drive/amicus-iv
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/amicus-iv

# %% [markdown]
# you'll need to enable GPUs for the notebook:
#
# - Navigate to Edit→Notebook Settings
# - select GPU from the Hardware Accelerator drop-down

# %%
import pandas as pd
import numpy as np
from html import unescape

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from collections import Counter

from transformers import AutoTokenizer
from datasets import load_dataset, load_metric, Dataset

from huggingface_hub import notebook_login

from bertopic import BERTopic
from flair.embeddings import TransformerDocumentEmbeddings
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ## Data
#
# BERTopic function takes a list of documents, so we need to set this up ourselves.

# %% [markdown]
# ## Option 0: Read in text from drive
#
# I have saved a file on google drive called "data/amicus_text_512.csv" which contains the result of following the steps of option 1 below. since this produces the same results each time, we don't need to keep re-running it.

# %%
df = pd.read_csv('data/amicus_text_512.csv')
df.head(5)
# Out:
#               case            id  \
# 0  Rust v Sullivan  861819857503
# 1  Rust v Sullivan  861819857503
# 2  Rust v Sullivan  861819857503
# 3  Rust v Sullivan  861819857503
# 4  Rust v Sullivan  861819857503
#
#                                                brief  brief_party  \
# 0  Rust v Sullivan. Amici Brief for Respondent, b...            0
# 1  Rust v Sullivan. Amici Brief for Respondent, b...            0
# 2  Rust v Sullivan. Amici Brief for Respondent, b...            0
# 3  Rust v Sullivan. Amici Brief for Respondent, b...            0
# 4  Rust v Sullivan. Amici Brief for Respondent, b...            0
#
#                                                 text
# 0  abortion battle conflict enumerated right life...
# 1  annual difficult case, ( based numbers since 1...
# 2  , believe state's interest protecting human li...
# 3  younger best facilities. least two definitions...
# 4  facilities. reasons, studies may apparently di...

# %% [markdown]
# ### Option 1: Tokenize text then decode back to original text

# %%
# !git config --global credential.helper store
# get access token on Huggingface website > settings > access token (make sure it's a write token)
notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token

# %% [markdown]
# Read in HF dataset

# %%
ds_path = 'repro-rights-amicus-briefs/repro-rights-amicus'
# use_auth_token must be true bc this is a private dataset
ds = load_dataset(ds_path, use_auth_token=True)

# remove html characters
ds = ds.map(
    lambda x: {'text': [unescape(o) for o in x['text']]}, batched=True
)

# remove stop words for topic modeling
stop_words = stopwords.words("english")
stopwords_dict = Counter(stop_words)

ds = ds.map(
    lambda x: {'text' : ' '.join([word for word in x['text'].split() if word not in stopwords_dict])}, batched=False
)

# %% [markdown]
# Tokenize

# %%
model_tokenizer = 'bert-base-uncased'

#instantiate tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_tokenizer)

# split documents into text of size 512 tokens
def tokenize_and_split(examples):
    result = tokenizer(
        examples["text"],
        truncation = True,
        max_length = 512,#512,
        stride = 128,
        return_overflowing_tokens = True,
        padding = 'max_length'
    )
    # Extract mapping between new and old indices
    sample_map = result.pop("overflow_to_sample_mapping")
    for key, values in examples.items():
        result[key] = [values[i] for i in sample_map]
    return result

# tokenize
tokenized_ds = ds.map(tokenize_and_split, batched = True, batch_size = 100)

# decode tokenized text back to original text 
def decode_chunks(example):
  result = tokenizer.batch_decode(
      example['input_ids'],
      skip_special_tokens=True,
      clean_up_tokenization_spaces=True
  )
  example['text_chunk'] = result
  return example

# decode
tokenized_ds = tokenized_ds.map(decode_chunks, batched=True, batch_size=100)
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]
#   0%|          | 0/5 [00:00<?, ?ba/s]
#   0%|          | 0/23 [00:00<?, ?ba/s]
#   0%|          | 0/28 [00:00<?, ?ba/s]
#   0%|          | 0/65 [00:00<?, ?ba/s]

# %% [markdown]
# Put document chunks into a list (since bertopic model only takes lists)

# %%
# new way using decoded tokenized text
sequences = tokenized_ds['train']['text_chunk'] + tokenized_ds['valid']['text_chunk'] + tokenized_ds['test']['text_chunk']
case = tokenized_ds['train']['case'] + tokenized_ds['valid']['case'] + tokenized_ds['test']['case']
brief_ids = tokenized_ds['train']['id'] + tokenized_ds['valid']['id'] + tokenized_ds['test']['id']
brief_names = tokenized_ds['train']['brief'] + tokenized_ds['valid']['brief'] + tokenized_ds['test']['brief']
brief_party = tokenized_ds['train']['brief_party'] + tokenized_ds['valid']['brief_party'] + tokenized_ds['test']['brief_party']

# check we have the results we expect
print(type(sequences))
print(type(sequences[0]))
print(len(sequences))
# Out:
# <class 'list'>
# <class 'str'>
# 11501

# %%
# save
df = pd.DataFrame({'case': case,
                   'id': brief_ids,
                   'brief' : brief_names,
                   'brief_party': brief_party,
                   'text': sequences})
df.to_csv('data/amicus_text_512.csv', index=False)

# %% [markdown]
# ### Option 2: split text by words

# %% [markdown]
# Define function to split text into 512 words. Since we aren't using huggingface pipelines, we have to make this rough cut and be okay with the fact that we're introducing inefficiencies into our process.

# %%
def split_text(text, n):
  # split text on space
  text = text.split()
  # grab tokens back into strings, with n words each 
  text = [' '.join(text[i:i+n]) for i in range(0,len(text),n)]

  return text

# %%
n = 512
df_512 = df.copy()
df_512['txt_split'] = df_512.apply(lambda row: split_text(row['txt_short'], n), axis=1)
df_512 = df_512.explode('txt_split')
df_512.drop('txt_short', axis=1, inplace=True)
df_512.rename({'txt_split': 'text'}, axis=1, inplace=True)
len(df_512)
# Out:
# 11804

# %%
df_512.head(1)
# Out:
#              case  ...                                               text
# 0  Anders v Floyd  ...  many roe v wade killings are murder the eviden...
#
# [1 rows x 4 columns]

# %% [markdown]
# Make a list of documents -- do not shuffle!

# %%
list_512 = list(df_512['text'])

# %% [markdown]
# # Part 1: Use fine-tuned transformer
#
# Flair allows you to choose almost any 🤗 transformers model. Select any public model from the HF model hub and pass it to BERTopic.

# %%
model_checkpoint = 'repro-rights-amicus-briefs/bert-base-uncased-finetuned-RRamicus'

# %% [markdown]
# ## Training

# %% [markdown]
# So, we can use our fine-tuned model here! Here, we use bert-base-uncased finetuned on our reproductive rights amicus.
#
# Note that you have to make the model public in order to do this.
#
# **Only do this once! Skip to 'load saved model' section if this has already been completed**
#
# Takes 9 minutes.

# %%
# init embeddings and model
bbu_ft_embed = TransformerDocumentEmbeddings(model_checkpoint)
bbu_ft_tm = BERTopic(embedding_model=bbu_ft_embed, language = 'english', calculate_probabilities=True, verbose=True)
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at repro-rights-amicus-briefs/bert-base-uncased-finetuned-RRamicus and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 11501it [08:11, 23.40it/s]
# 2022-03-21 19:16:12,594 - BERTopic - Transformed documents to Embeddings
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)
# 2022-03-21 19:16:45,045 - BERTopic - Reduced dimensionality with UMAP
# 2022-03-21 19:16:52,868 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %% [markdown]
# Fit the model to our data (9 mins)

# %%
# fit model
bbu_ft_topics, bbu_ft_probs = bbu_ft_tm.fit_transform(df['text'])
# Out:
# 11501it [08:44, 21.92it/s]
# 2022-03-21 19:31:17,761 - BERTopic - Transformed documents to Embeddings
# 2022-03-21 19:31:31,987 - BERTopic - Reduced dimensionality with UMAP
# 2022-03-21 19:31:40,939 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %% [markdown]
# Save model

# %%
bbu_ft_tm.save('bbu_rramicus')

# %% [markdown]
# ## Extract Topics
#
# Only do this once; once saved, skip to next section.

# %%
bbu_ft_freq = bbu_ft_tm.get_topic_info()
bbu_ft_freq.head(10)
# Out:
#    Topic  Count                                          Name
# 0     -1   5933                 -1_abortion_court_state_right
# 1      0    378     0_respectfully_counsel_submitted_attorney
# 2      1    243                  1_zone_buffer_content_speech
# 3      2    204              2_casey_undue_burden_regulations
# 4      3    178          3_injunction_speech_picketing_public
# 5      4    178                         4_intact_tr_dr_chasen
# 6      5    166  5_adolescents_adolescent_study_psychological
# 7      6    139       6_conclusion_reasons_judgment_foregoing
# 8      7    138             7_title_planning_program_services
# 9      8    123                 8_clinic_1993_violence_rescue

# %% [markdown]
# Save files -- make sure to change file names!

# %%
# full list of topics + associated words
bbu_ft_freq.to_csv('output/topics_bbu_rramicus.csv', index=False)

# classification by paragraph
topic_id = bbu_ft_freq[['Topic', 'Name']]
output_df = df.copy()
output_df['topic_id'] = bbu_ft_topics
output_df = output_df.merge(topic_id, how='left', left_on='topic_id', right_on='Topic')
output_df.drop('Topic',axis=1,inplace=True)
output_df.rename({'Name' : 'topic_name'},axis=1, inplace=True)
output_df.to_csv('output/topic_classification_bbu_rramicus.csv', index=False)

# %% [markdown]
# Get similar topics to a word

# %%
similar_topics, similarity = bbu_ft_tm.find_topics("physician", top_n=5)
print(similar_topics)
bbu_ft_tm.get_topic(similar_topics[1])
# Out:
# [121, 83, 144, 55, 131]
# [('462', 0.02527786069940472),
#  ('physician', 0.022643759939560082),
#  ('akron', 0.022515536622137674),
#  ('compelling', 0.017801932667464677),
#  ('state', 0.013705446020272091),
#  ('minor', 0.01338338044260382),
#  ('decision', 0.01295395091522947),
#  ('city', 0.012829252289062735),
#  ('patient', 0.01267554983802088),
#  ('medical', 0.012218936239160334)]

# %%
representative_docs = bbu_ft_tm.get_representative_docs(85)
representative_docs
# Out:
# ["statute purpose evading judicial review. 2 b. section 6 ( 1 ) illinois abortion law, amended 1979, prescribed standard care doctor performing abortion “ after fetus known viable ” ( 84 - 1379 j. s. app. 6 ). november 16, 1979, four days statute became effective, district court preliminarily enjoined enforcement, finding incorporated unconstitutional definition viability ( id. 3 ). september 1983, illinois legislature amended definition viability, providing fetus viable “ when, medical judgment attending physician based particular facts case him, reasonable likelihood sustained survival fetus outside womb, without artificial support ” ( id. 7, 58 ). october 14, 1983, district court sustained amended definition * 13 viability, held section 6 ( 1 ) thus constitutional, lifted preliminary injunction ( 579 f. supp. 466, 469 ). june 30, 1984, instant appeal pending seventh circuit, illinois legislature amended section 6 ( 1 ) ( see 84 - 1379 j. s. app. 7, 57 - 58 ). court appeals recognized amendment “ substantially transformed section 6 ( 1 ) ” court “ accordingly decline [ d ] discuss constitutionality ” current version ( id. 7 ). again, however, court appeals proceeded declare repealed version statute unconstitutional. rejecting state's suggestion mootness, court noted old section 6 ( 1 ) operative effect eight - month period october 14, 1983, june 30, 1984. court observed statute limitations expired respect events occurring period, hence suggested state “ could prosecute plaintiffs * * * [ they ] violated [ the repealed ] section remained effect ” ( 84 - 1379 j. s. app. 15 ). court found “ this possibility insufficiently speculative render [ their ] challenge * * * moot ” ( id. 16 ). court's reasoning flawed. state explicitly advised court appeals would initiate prosecutions type appellees assertedly feared ( see 84 - 1379 j. s. 42, 48 ). moreover, appellees brought facial challenge section 6 ( 1 ) allege performed late - term abortions eight - month period question ( see id. 43 ). possibility appellees might prosecuted old statute thus conjectural satisfy article iii requirements. see, e. g., los angeles v. lyons, 461 u. s. 95, 101 - 110 ( 1983 ) ; poe v. ullman, 367 u. s. 497, 507 ( 1961 ). merits, court appeals held old version section 6 ( 1 ) unconstitutional",
# %% [markdown]
# ## Load saved model
#
# Run this code if the previous sections (training, extract topics) have already been run once

# %%
# read in model
bbu_ft_tm = BERTopic.load("bbu_rramicus")
# frequency of each topic
bbu_ft_freq = bbu_ft_tm.get_topic_info()
# full topics
bbu_ft_topics = bbu_ft_tm.get_topics()

# %% [markdown]
# ## Visualize Topics

# %%
bbu_ft_tm.visualize_topics()
# Out:
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cf0a0a45-8f57-4847-847f-4dcbf066801c" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf0a0a45-8f57-4847-847f-4dcbf066801c")) {                    Plotly.newPlot(                        "cf0a0a45-8f57-4847-847f-4dcbf066801c",                        [{"customdata":[[0,"respectfully | counsel | submitted | attorney | curiae",378],[1,"zone | buffer | content | speech | hill",243],[2,"casey | undue | burden | regulations | regulation",204],[3,"injunction | speech | picketing | public | conduct",178],[4,"intact | tr | dr | chasen | birth",178],[5,"adolescents | adolescent | study | psychological | pregnancy",166],[6,"conclusion | reasons | judgment | foregoing | court",139],[7,"title | planning | program | services | programs",138],[8,"clinic | 1993 | violence | rescue | clinics",123],[9,"stenberg | court | exception | partial | 530",98],[10,"casey | standing | burden | party | health",79],[11,"supreme | evidence | any | murder | wade",78],[12,"madsen | injunction | speech | zone | 114",76],[13,"interest | compelling | state | right | roe",75],[14,"minors | parental | minor | notification | parents",74],[15,"3205 | section | information | informed | 3206",69],[16,"rico | 1964 | enterprise | relief | equitable",60],[17,"hobbs | extortion | robbery | violence | act",57],[18,"fetus | act | physician | minor | medical",56],[19,"maher | danforth | state | matheson | 432",55],[20,"1985 | class | animus | gender | conspiracy",54],[21,"ul0 | b0 | i0 | pard | par",54],[22,"teenage | girls | women | likely | teenagers",52],[23,"physician | patient | fertilized | information | contraceptives",51],[24,"texas | care | 2015 | http | women",50],[25,"knew | wanted | would | able | amy",50],[26,"life | human | marriage | child | rights",50],[27,"whole | privileges | admitting | louisiana | fifth",48],[28,"state | statute | woman | childbirth | court",48],[29,"compelling | roe | interest | 428 | state",46],[30,"baby | human | fluid | heart | mother",44],[31,"murder | alive | 1868 | born | english",43],[32,"hellerstedt | casey | burden | benefits | undue",41],[33,"trimester | second | hospitals | performed | abortions",41],[34,"standing | party | third | singleton | tertii",40],[35,"person | wade | unborn | preamble | roe",39],[36,"al | et | women | 2011 | risk",38],[37,"right | fundamental | liberty | privacy | rights",38],[38,"salerno | facial | overbreadth | challenges | challenge",37],[39,"murder | unborn | any | decreed | jews",37],[40,"danforth | physician | trimester | woman | consent",35],[41,"court | roe | children | rights | laws",35],[42,"roe | court | state | id | statute",35],[43,"bellotti | minor | parental | parents | 443",35],[44,"religious | right | 381 | children | meyer",34],[45,"compelling | 410 | strict | interest | maternal",33],[46,"620 | louisiana | act | admitting | privileges",33],[47,"petitioners | 1008 | hobbs | title | civil",33],[48,"trimester | akron | hospitalization | licensed | waiting",32],[49,"texas | 2015 | http | www | dec",31],[50,"old | years | pregnant | child | husband",31],[51,"credentialing | privileges | hospital | ms | 01",30],[52,"university | prof | college | ethics | california",29],[53,"human | ethic | life | child | person",29],[54,"teenagers | cates | adolescent | pregnancy | trimester",29],[55,"church | religious | jewish | convention | moral",28],[56,"decisis | stare | precedent | roe | doctrine",28],[57,"industry | privileges | abortion | 23a | louisiana",28],[58,"roe | right | liberty | privacy | fundamental",27],[59,"murder | mass | supreme | jews | nazi",27],[60,"century | nineteenth | quickening | became | twentieth",27],[61,"unborn | appropriations | life | personhood | court",26],[62,"18340113 | 15 ...

# %% [markdown]
# ## Topics per class

# %% [markdown]
# We can divide up the topics into those that appear in one class vs the other (fem briefs and opp briefs)

# %%
topics_per_class = bbu_ft_tm.topics_per_class(sequences, bbu_ft_topics, brief_party)
topics_per_class.head(10)
# Out:
#    Topic                                             Words  Frequency  Class
# 0     -1                         the, of, to, in, abortion       3693      0
# 1      0                speech, or, injunction, hobbs, the        991      0
# 2      1                               ul0, b0, of, at, in       1005      0
# 3      2             casey, undue, burden, at, regulations        240      0
# 4      3          title, program, funds, regulations, 1008        139      0
# 5      4     murder, supreme, unborn, constitution, person        273      0
# 6      5                  texas, hb2, clinics, women, http         48      0
# 7      6  minor, parental, notification, parents, decision         68      0
# 8      7                            my, me, was, baby, had         47      0
# 9      8            roe, constitutional, court, wade, this         69      0

# %%
#fem_brief_bbu_topics = topics_per_class[topics_per_class['Class']==1].drop(['Class'],axis=1,inplace=False)
bbu_ft_tm.visualize_topics_per_class(topics_per_class, top_n_topics=5, normalize_frequency=True)

# %% [markdown]
# ## Reduce n topics
#
# This is a manual decision

# %%
#new_topics, new_probs = topic_model.reduce_topics(list_512, topics, probs, nr_topics=60)

# %% [markdown]
# ## Topic hierarchy
#
# Another way to visually examine how topcis are related to one another. Just from looking on this, I think it would make more sense to topic model pro-women and pro-opp briefs separately, since they often use similar language/topics but are articulating very different points on them!

# %%
topic_model.visualize_hierarchy(top_n_topics=25)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="07bfee39-370d-4819-b4aa-120b1559b162" class="plotly-graph-div" style="height:575px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07bfee39-370d-4819-b4aa-120b1559b162")) {                    Plotly.newPlot(                        "07bfee39-370d-4819-b4aa-120b1559b162",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.33980385190301493,0.33980385190301493,0.0],"xaxis":"x","y":[-35.0,-35.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.6204776910860709,0.6204776910860709,0.33980385190301493],"xaxis":"x","y":[-25.0,-25.0,-40.0,-40.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.6763740092126082,0.6763740092126082,0.6204776910860709],"xaxis":"x","y":[-15.0,-15.0,-32.5,-32.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.8270868906562396,0.8270868906562396,0.6763740092126082],"xaxis":"x","y":[-5.0,-5.0,-23.75,-23.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.4025562743214623,0.4025562743214623,0.0],"xaxis":"x","y":[-65.0,-65.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.4706462679068608,0.4706462679068608,0.4025562743214623],"xaxis":"x","y":[-55.0,-55.0,-70.0,-70.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.44551106774501753,0.44551106774501753,0.0],"xaxis":"x","y":[-95.0,-95.0,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.44071765110451094,0.44071765110451094,0.0],"xaxis":"x","y":[-125.0,-125.0,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.4983655199553242,0.4983655199553242,0.44071765110451094],"xaxis":"x","y":[-115.0,-115.0,-130.0,-130.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.44551106774501753,0.5459290208666204,0.5459290208666204,0.4983655199553242],"xaxis":"x","y":[-100.0,-100.0,-122.5,-122.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.5604175582050198,0.5604175582050198,0.5459290208666204],"xaxis":"x","y":[-85.0,-85.0,-111.25,-111.25],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.4706462679068608,0.7124603793587322,0.7124603793587322,0.5604175582050198],"xaxis":"x","y":[-62.5,-62.5,-98.125,-98.125],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.3684431892477703,0.3684431892477703,0.0],"xaxis":"x","y":[-145.0,-145.0,-155.0,-155.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.38280087104837673,0.38280087104837673,0.0],"xaxis":"x","y":[-165.0,-165.0,-175.0,-175.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.4214536372128991,0.4214536372128991,0.0],"xaxis":"x","y":[-195.0,-195.0,-205.0,-205.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.43558376997834697,0.43558376997834697,0.4214536372128991],"xaxis":"x","y":[-185.0,-185.0,-200.0,-200.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.38280087104837673,0.5488263682706 ...

# %% [markdown]
# ## Topic Similarity
#
# Having generated topic embeddings, through both c-TF-IDF and embeddings, we can create a similarity matrix by simply applying cosine similarities through those topic embeddings. The result will be a matrix indicating how similar certain topics are to each other.

# %%
topic_model.visualize_heatmap(n_clusters=10, width=1000, height=1000)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="
# %%
seed_topic_list = [['physician', 'doctor', 'medical professional', 'medical expert'], ['women', 'mother']]
seed_topic_model = BERTopic(language = 'english', calculate_probabilities=True, verbose=True,
                            seed_topic_list = seed_topic_list)
seed_topics, seed_probs = seed_topic_model.fit_transform(sequences)
# Out:
# Batches:   0%|          | 0/498 [00:00<?, ?it/s]
# 2022-03-16 17:40:37,439 - BERTopic - Transformed documents to Embeddings
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2022-03-16 17:41:03,827 - BERTopic - Reduced dimensionality with UMAP
# 2022-03-16 17:41:24,975 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %%
seed_freq = seed_topic_model.get_topic_info()
seed_freq.head(10)
# Out:
#    Topic  Count                                        Name
# 0     -1   5744                            -1_the_to_of_and
# 1      0    473             0_parental_minors_parents_minor
# 2      1    372          1_court_federal_courts_legislative
# 3      2    303  2_mortality_pregnancy_complications_deaths
# 4      3    265                   3_hill_zone_buffer_speech
# 5      4    224                    4_roe_privacy_wade_right
# 6      5    200        5_louisiana_620_privileges_admitting
# 7      6    180          6_psychological_women_study_mental
# 8      7    179          7_children_parents_family_parental
# 9      8    171                       8_human_life_being_we

# %%
seed_women_similar_topics, seed_women_similarity = seed_topic_model.find_topics("women's rights", top_n=5)
print(seed_women_similar_topics)
seed_topic_model.get_topic(seed_women_similar_topics[0])
# Out:
# [165, 139, 86, 91, 127]
# [('women', 0.014136297774918507),
#  ('laws', 0.011999050580616942),
#  ('illegal', 0.010237065081556607),
#  ('enforcement', 0.009734576408527344),
#  ('dying', 0.0094023498417061),
#  ('abortions', 0.009385982433003582),
#  ('rape', 0.008878073201327344),
#  ('incest', 0.008369399996816313),
#  ('prosecution', 0.0077237846543999214),
#  ('criminal', 0.007508319106164667)]

# %%
seed_phys_similar_topics, seed_phys_similarity = seed_topic_model.find_topics("doctor", top_n=5)
print(seed_phys_similar_topics)
seed_topic_model.get_topic(seed_phys_similar_topics[1])
# Out:
# [164, 66, 77, 93, 11]
# [('hospital', 0.02913038745081937),
#  ('credentialing', 0.025738828794159216),
#  ('privileges', 0.022390621401369354),
#  ('hospitals', 0.019021824083630595),
#  ('care', 0.016055733923885766),
#  ('staff', 0.015923603500972786),
#  ('physician', 0.015268006792430806),
#  ('ms', 0.015124700368570216),
#  ('admitting', 0.012263187376225206),
#  ('physicians', 0.011998829970855503)]

# %% [markdown]
# # Part 3: Split into fem and opp

# %% [markdown]
# In this section, we fit models for fem and opp briefs separately in order to get more specific topic information.

# %%
# split data
opp_df = df[df['brief_party']==0]
fem_df = df[df['brief_party']==1]

# %% [markdown]
# ## Fem topic model

# %% [markdown]
# Init existing topic model again so we don't over-write existing model.

# %%
fem_tm = BERTopic.load("bbu_rramicus")

# %% [markdown]
# Fit the model on only the docs of interest (5 min)

# %%
# fit model
fem_topics, fem_probs = fem_tm.fit_transform(fem_df['text'])
# Out:
# 5227it [05:18, 16.42it/s]

# %%
fem_topic_info = fem_tm.get_topic_info()
fem_topic_info.head(5)
# Out:
#    Topic  Count                                     Name
# 0     -1   2210            -1_court_abortion_state_right
# 1      0    607              0_texas_women_abortion_2015
# 2      1    130  1_counsel_respectfully_street_submitted
# 3      2     92                2_clinic_1993_dr_violence
# 4      3     82              3_would_could_able_abortion

# %%
fem_tm.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="
# Out:
# [57, 46, -1, 35, 59]
# [0.9860490372255521, 0.9815115778404839, 0.9811166197960979, 0.9800830365274396, 0.9793343559125567]
# [('act', 0.01543954118686647), ('emergency', 0.014231235818460135), ('medical', 0.013855040367193103), ('physician', 0.01369661624339168), ('patient', 0.013609853728641), ('hampshire', 0.012316739126711787), ('health', 0.012138903189156435), ('abortion', 0.01207191176826808), ('physicians', 0.011911218625010789), ('judge', 0.011798782385998659)]
# [('organization', 0.03879029805705921), ('rights', 0.028612205730736546), ('reproductive', 0.02238318008521494), ('national', 0.021545567586049752), ('women', 0.021178794951134908), ('civil', 0.01938167511672356), ('legal', 0.01754986814847482), ('education', 0.016915347950587963), ('health', 0.01645128531672538), ('advocacy', 0.015872087366163745)]
# [('court', 0.009003044817547996), ('abortion', 0.0078714103351809), ('state', 0.007542976329646191), ('right', 0.006502928377333628), ('health', 0.006451944211089597), ('women', 0.00628211346849032), ('woman', 0.006266423372504197), ('see', 0.005985952998052546), ('medical', 0.005910533099113882), ('statute', 0.005828952477247492)]
# [('minor', 0.02253664294520492), ('physician', 0.01911903029869337), ('medical', 0.015238959521692418), ('1870', 0.014850782318519393), ('parental', 0.014478006661840431), ('patient', 0.013909005609166008), ('section', 0.013478723873516106), ('necessary', 0.012748268196019664), ('statute', 0.012067505073100435), ('fetus', 0.011917770854811872)]
# [('rico', 0.02617814602973453), ('congress', 0.024102471945680673), ('organized', 0.020998641848315364), ('crime', 0.020592061873714665), ('commerce', 0.019500427911417536), ('interstate', 0.01721731870925849), ('sedima', 0.017130593781134563), ('economic', 0.014819023408373594), ('statute', 0.014761372583071015), ('statutory', 0.014756120240439744)]

# %% [markdown]
# Save

# %%
# full list of topics + associated words
fem_topic_info.to_csv('output/fem_topics_bbu_rramicus.csv', index=False)

# classification by paragraph
topic_id = fem_topic_info[['Topic', 'Name']]
output_df = fem_df.copy()
output_df['topic_id'] = fem_topics
output_df = output_df.merge(topic_id, how='left', left_on='topic_id', right_on='Topic')
output_df.drop('Topic',axis=1,inplace=True)
output_df.rename({'Name' : 'topic_name'},axis=1, inplace=True)
output_df.to_csv('output/fem_topic_classification_bbu_rramicus.csv', index=False)

# %%
fem_tm.save('fem_bbu_rramicus')

# %% [markdown]
# ## Opp topic model

# %% [markdown]
# Init existing topic model again so we don't over-write existing model.

# %%
opp_tm = BERTopic.load("bbu_rramicus")

# %% [markdown]
# Fit the model on only the docs of interest (5 min)

# %%
# fit model
opp_topics, opp_probs = opp_tm.fit_transform(opp_df['text'])
# Out:
# 6274it [05:33, 18.83it/s]

# %%
opp_topic_info = opp_tm.get_topic_info()
opp_topic_info.head(5)
# Out:
#    Topic  Count                                       Name
# 0     -1   3024              -1_abortion_court_state_right
# 1      0    189  0_respectfully_counsel_submitted_attorney
# 2      1    141             1_hobbs_extortion_act_property
# 3      2    138                  2_life_child_unborn_human
# 4      3    131              3_any_supreme_unborn_evidence

# %%
#opp_tm.visualize_topics(top_n_topics=50)
opp_tm.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fd78a071-da8c-4b2f-b0c2-c6ecf695a87d" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd78a071-da8c-4b2f-b0c2-c6ecf695a87d")) {                    Plotly.newPlot(                        "fd78a071-da8c-4b2f-b0c2-c6ecf695a87d",                        [{"customdata":[[0,"respectfully | counsel | submitted | attorney | general",189],[1,"hobbs | extortion | act | property | violence",141],[2,"life | child | unborn | human | right",138],[3,"any | supreme | unborn | evidence | murder",131],[4,"content | hill | speech | neutral | zone",124],[5,"stenberg | court | federal | case | statute",119],[6,"court | children | parents | parental | state",113],[7,"standing | party | third | rights | providers",111],[8,"speech | injunction | public | picketing | streets",105],[9,"burden | fraction | undue | test | large",101],[10,"conclusion | court | judgment | reasons | reversed",77],[11,"casey | undue | burden | regulations | health",74],[12,"title | program | services | planning | section",73],[13,"human | weeks | baby | mother | child",65],[14,"century | murder | common | abortion | law",62],[15,"unborn | life | posterity | person | human",56],[16,"interest | state | compelling | roe | decision",55],[17,"ul0 | b0 | i0 | pard | par",54],[18,"age | birth | rate | intact | year",53],[19,"1985 | class | animus | gender | travel",49],[20,"fundamental | liberty | right | roe | due",46],[21,"madsen | injunction | speech | clinic | 114",46],[22,"hb2 | asc | texas | clinics | rep",45],[23,"hellerstedt | casey | benefits | burden | undue",41],[24,"undue | gonzales | casey | burden | 550",40],[25,"murder | alive | 1868 | common | english",39],[26,"deaths | mortality | abortion | pregnancy | cdc",39],[27,"adolescents | adolescent | parental | parents | teenagers",36],[28,"patient | informed | consent | disclosure | physician",35],[29,"unborn | child | human | life | person",33],[30,"roe | akron | right | abortion | state",32],[31,"pregnancy | rate | deaths | women | suicide",32],[32,"murder | supreme | mass | officials | constitution",30],[33,"gosnell | 2019 | incl | grand | report",29],[34,"minor | parents | bellotti | parental | family",28],[35,"http | www | jan | com | 2016",27],[36,"sidewalk | counseling | buffer | clinic | speech",26],[37,"posterity | perpetuities | framer | common | fee",26],[38,"hyperlink | contentitem | urn | api | lexis",25],[39,"state | court | maher | funding | 432",25],[40,"roe | wade | law | court | abortion",25],[41,"privileges | louisiana | admitting | hospital | 2015",25],[42,"god | life | human | one | society",25],[43,"women | abortion | rutherford | abortive | partial",23],[44,"fetal | gestational | age | lung | maturity",23],[45,"84 | section | 495 | app | 1379",23],[46,"study | abortions | women | psychological | induced",22],[47,"parents | decision | parental | matheson | minor",21],[48,"declaration | any | constitution | person | spirit",21],[49,"akron | maher | 432 | connor | state",21],[50,"mathematical | constitution | certainty | mathematics | words",21],[51,"parental | akron | consent | state | minor",20],[52,"salerno | facial | cir | 3d | challenge",20],[53,"baby | month | child | muscles | fig",18],[54,"statute | abortion | supra | state | woman",18],[55,"june | standing | party | patients | third",17],[56,"122 | 18 | feet | colorado | speaker",17],[57,"gynec | obstet | vol | 1969 | no",17],[58,"fetus | act | partial | body | birth",17],[59,"3205 | information | section | akron | informed",16],[60,"nations | appeal | law | just | posterity",16],[61,"powers | ninth | rights | retained | madison",16],[62,"partial | respondents | act | birth | abortion",15],[63,"vagueness | adult | process | child | court",15],[64,"pet ...

# %%
# full list of topics + associated words
opp_topic_info.to_csv('output/opp_topics_bbu_rramicus.csv', index=False)

# classification by paragraph
topic_id = opp_topic_info[['Topic', 'Name']]
output_df = opp_df.copy()
output_df['topic_id'] = opp_topics
output_df = output_df.merge(topic_id, how='left', left_on='topic_id', right_on='Topic')
output_df.drop('Topic',axis=1,inplace=True)
output_df.rename({'Name' : 'topic_name'},axis=1, inplace=True)
output_df.to_csv('output/opp_topic_classification_bbu_rramicus.csv', index=False)

# %%
opp_tm.save('opp_bbu_rramicus')
